# %% [markdown]
# # Task : Session 1
# Solve these questions own your own and try to test yourself what you have learned in the session.
#
# Happy Learning!

# %% [markdown]
# ### Q1 :- Print the given strings as per stated format.
#
# **Given strings**:
# ```
# "Data" "Science" "Mentorship" "Program"
# "By" "CampusX"
# ```
# **Output**:
# ```
# Data-Science-Mentorship-Program-started-By-CampusX
# ```
#
# Concept- [Seperator and End]

# %%
# Write your code here
str1 = 'Data'
str2 = 'Science'
str3 = 'Mentorship'
str4 = 'Program'
str5 = 'By'
str6 = 'CampusX'
print(str1,str2,str3,str4,sep='-',end='-started-')
print(str5,str6,sep='-')
# Out:
# Data-Science-Mentorship-Program-started-By-CampusX

# %% [markdown]
# ### Q2:- Write a program that will convert celsius value to fahrenheit.

# %%
# Write your code here
temp_in_celcius = float(input('Enter the temperature in degree celcius:'))
temp_in_fahrenheit = (temp_in_celcius * 1.8) + 32
print(f'temp in fahrenheit is {temp_in_fahrenheit}')
# Out:
# temp in fahrenheit is 89.6

# %% [markdown]
# ### Q3:- Take 2 numbers as input from the user.Write a program to swap the numbers without using any special python syntax.

# %%
# Write your code here
num1 = int(input('enter the first number:'))
num2 = int(input('enter the second number:'))
num1 = num1 + num2
num2 = num1 - num2
num1 = num1 - num2
print(f'first number is {num1}\nsecond number is {num2}')
# Out:
# first number is 6
# second number is 4

# %% [markdown]
# ### Q4:- Write a program to find the euclidean distance between two coordinates.Take both the coordinates from the user as input.

# %%
# Write your code here
class Point:
    
    def __init__(self,x_coordinate,y_coordinate):
        self.x_coordinate = x_coordinate
        self.y_coordinate = y_coordinate

    def euclidean_distance(self,other):
        return ((self.x_coordinate - other.x_coordinate)**2 + (self.y_coordinate - other.y_coordinate)**2)**0.5

# %%
point1 = Point(3,4)
point2 = Point(1,4)
print(f'euclidean distance between these points is {point1.euclidean_distance(point2)}')
# Out:
# euclidean distance between these points is 2.0

# %% [markdown]
# ### Q5:- Write a program to find the simple interest when the value of principle,rate of interest and time period is provided by the user.

# %%
# Write your code here
principle = int(input('enter the amount or principle:'))
rate_of_interest = int(input('enter the rate of interest:'))
time_period = int(input('enter the time period:'))
simple_interest = principle * (rate_of_interest/100) * time_period
print('simple interest is:',simple_interest)
# Out:
# simple interest is: 24000.0

# %% [markdown]
# ### Q6:- Write a program that will tell the number of dogs and chicken are there when the user will provide the value of total heads and legs.
#
# For example:
# Input:
# heads -> 4
# legs -> 12
# <br>
# Output:
# dogs -> 2
# chicken -> 2

# %%
# Write your code here
heads = int(input('enter the no of heads:'))
legs = int(input('enter the no of legs:'))
dogs = legs / 2 - heads
chicken = heads - dogs
print(f"dogs -> {dogs}\nchicken -> {chicken}")
# Out:
# dogs -> 2.0
# chicken -> 2.0

# %% [markdown]
# ### Q7:- Write a program to find the sum of squares of first n natural numbers where n will be provided by the user.

# %%
# Write your code here
n = int(input('enter the the value of n:'))
squared_sum_first_n_natural_numbers = (n*(n+1)*(2*n+1))/6
print(f'squared sum of first n natural numbers is {squared_sum_first_n_natural_numbers}')
# Out:
# squared sum of first n natural numbers is 30.0

# %% [markdown]
# ### Q8:- Given the first 2 terms of an Arithmetic Series.Find the Nth term of the series. Assume all inputs are provided by the user.

# %%
# Write your code here
first_term = int(input('enter the first term:'))
second_term = int(input('enter the second term:'))
nth_value = int(input('enter the n number you want to find:'))
diff = second_term - first_term
nth_term = first_term + (nth_value - 1) * diff
print(f'nth term is {nth_term}')
# Out:
# nth term is 5

# %% [markdown]
# ### Q9:- Given 2 fractions, find the sum of those 2 fractions.Take the numerator and denominator values of the fractions from the user.

# %%
# Write your code here
class Fraction:

    def __init__(self,numerator,denominator):
        self.numerator = numerator
        self.denominator = denominator

    def __add__(self,other):
        new_numerator = self.numerator*other.denominator + other.numerator*self.denominator
        new_denominator = self.denominator * other.denominator
        return Fraction(new_numerator,new_denominator)
    def __str__(self):
        return f'{self.numerator}/{self.denominator}'

# %%
first = Fraction(1,2)
second = Fraction(3,4)
third = first + second
print(third)
# Out:
# 10/8

# %% [markdown]
# ### Q10:- Given the height, width and breadth of a milk tank, you have to find out how many glasses of milk can be obtained? Assume all the inputs are provided by the user.
#
#
#
# Input:<br>
# Dimensions of the milk tank<br>
# H = 20cm, L = 20cm, B = 20cm
# <br><br>
# Dimensions of the glass<br>
# h = 3cm, r = 1cm

# %%
# Write your code here
height_milk_tank = int(input('enter the heigt of the tank:'))
length_milk_tank = int(input('enter the length of the tank:'))
breadth_milk_tank = int(input('enter the breadth of the tank:'))
height_glass = int(input('enter the height of glass:'))
radius_glass = int(input('enter the radius of glass:'))
no_of_glasses = int((height_milk_tank * length_milk_tank * breadth_milk_tank) / (3.14 * radius_glass**2 * height_glass))
print(f'no of glasses milk obtained is {no_of_glasses}')
# Out:
# no of glasses milk obtained is 2.1231422505307855
